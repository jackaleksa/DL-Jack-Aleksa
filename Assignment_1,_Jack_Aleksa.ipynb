# %% [markdown]
# <a href="https://colab.research.google.com/github/jackaleksa/DL-Jack-Aleksa/blob/main/Assignment_1%2C_Jack_Aleksa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
image = Image.open('Hungflag.png')
pixel_map = image.load()
width,length = image.size
for w in range(width-30, width):
  for l in range(30):
    pixel_map[w,l] = (0,0,0)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x400 at 0x7F602EACC490>
